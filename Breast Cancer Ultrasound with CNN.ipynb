# %% [markdown]
# # <div align="center"> Utilizing SVM and CNN Models for Breast Cancer Detection with Mammography and Ultrasound Imaging </div>
#
# Group 5:
# * Almira Zahra Aurelia – 00000080298
# * Darren Irawan Djong – 00000081041
# * Kayla Abigail Gunawan – 00000081824
# * Sabrina Fajrul Ula Usman – 00000083124

# %% [markdown]
# # Convolutional Neural Networks (CNN)
#
# Ultrasound Image Dataset

# %%
import os
import cv2
import numpy as np
import seaborn as sns
import pandas as pd
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# Define data paths
data_path = "C:/Users/Hp/MACHINE LEARNING/Lab/ML PROJECT/image ml/Dataset_BUSI_with_GT"
benign_path = os.path.join(data_path, "benign")
malignant_path = os.path.join(data_path, "malignant")
normal_path = os.path.join(data_path, "normal")

# %%
# Load images and labels
def load_images(folder_path, label):
    images = []
    labels = []
    for filename in tqdm(os.listdir(folder_path)):
        try:
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)  # Read image without specifying grayscale
            if img is None:
                print(f"Warning: Unable to read image {img_path}. Skipping...")
                continue
            img = cv2.resize(img, (100, 100))  # Resize the image as needed
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            images.append(img)
            labels.append(label)
        except Exception as e:
            print(f"Error occurred while processing image {img_path}: {e}")
    return images, labels

# %%
# Load images and labels
benign_images, benign_labels = load_images(benign_path, "benign")
malignant_images, malignant_labels = load_images(malignant_path, "malignant")
normal_images, normal_labels = load_images(normal_path, "normal")
# Out:
# 100%|██████████| 437/437 [00:04<00:00, 108.65it/s]
# 100%|██████████| 210/210 [00:01<00:00, 114.95it/s]
# 100%|██████████| 133/133 [00:01<00:00, 95.36it/s]

# %%
# Combine images and labels
all_images = benign_images + malignant_images + normal_images
all_labels = benign_labels + malignant_labels + normal_labels

# %%
# Convert to numpy arrays
X = np.array(all_images)
y = np.array(all_labels)

# %%
np.unique(y)
# Out:
# array(['benign', 'malignant', 'normal'], dtype='<U9')

# %%
import pandas as pd

pd.Series(y).value_counts()
# Out:
# benign       437
# malignant    210
# normal       133
# Name: count, dtype: int64

# %%
# Encode class labels into integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded, num_classes=3)

# %%
# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, y_categorical, random_state=42, test_size=0.2)

# %%
# Reshape and normalize data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# Menampilkan bentuk data latih dan data uji untuk memeriksa apakah dimensinya sesuai.
print("Shape of x_train: {}".format(x_train.shape))
print("Shape of y_train: {}".format(y_train.shape))
print()
print("Shape of x_test: {}".format(x_test.shape))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of x_train: (624, 100, 100, 3)
# Shape of y_train: (624, 3)
#
# Shape of x_test: (156, 100, 100, 3)
# Shape of y_test: (156, 3)

# %% [markdown]
# # Let's display as image

# %%
# Display as image
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
digit = 4 # Change to choose new digit
a = x_train[digit]
plt.imshow(a, cmap='gray', interpolation='nearest')
print("Image (#{}): Which is digit '{}'".format(digit,y_train[digit]))
# Out:
# Image (#4): Which is digit '[1. 0. 0.]'

# %% [markdown]
# # SHOW MORE RANDOM DATA

# %%
def show_random_image_samples(x_data, y_data, num_samples=25):
    # Randomly select indices
    indices = np.random.choice(range(x_data.shape[0]), num_samples, replace=False)
    images = x_data[indices]
    labels = y_data[indices]

    plt.figure(figsize=(20, 20))
    for i in range(num_samples):
        plt.subplot(5, 5, i + 1)
        # Remove the reshape operation
        image = images[i]
        label_index = np.argmax(labels[i])
        label_name = label_encoder.inverse_transform([label_index])[0]
        plt.imshow(image, cmap='gray')
        plt.title(label_name, color='black', fontsize=16)
        plt.axis('off')
    plt.show()

# Show random samples
show_random_image_samples(x_train, y_train)

# %% [markdown]
# # CREATE THE MODEL

# %%
import tensorflow as tf
from tensorflow.keras.applications import Xception

base_model = Xception(weights='imagenet', include_top=False, input_shape=(100, 100, 3))
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 49, 49, 32)   864         ['input_1[0][0]']
#
#  block1_conv1_bn (BatchNormaliz  (None, 49, 49, 32)  128         ['block1_conv1[0][0]']
#  ation)
#
#  block1_conv1_act (Activation)  (None, 49, 49, 32)   0           ['block1_conv1_bn[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 47, 47, 64)   18432       ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNormaliz  (None, 47, 47, 64)  256         ['block1_conv2[0][0]']
#  ation)
#
#  block1_conv2_act (Activation)  (None, 47, 47, 64)   0           ['block1_conv2_bn[0][0]']
#
#  block2_sepconv1 (SeparableConv  (None, 47, 47, 128)  8768       ['block1_conv2_act[0][0]']
#  2D)
#
#  block2_sepconv1_bn (BatchNorma  (None, 47, 47, 128)  512        ['block2_sepconv1[0][0]']
#  lization)
#
#  block2_sepconv2_act (Activatio  (None, 47, 47, 128)  0          ['block2_sepconv1_bn[0][0]']
#  n)
#
#  block2_sepconv2 (SeparableConv  (None, 47, 47, 128)  17536      ['block2_sepconv2_act[0][0]']
#  2D)
#
#  block2_sepconv2_bn (BatchNorma  (None, 47, 47, 128)  512        ['block2_sepconv2[0][0]']
#  lization)
#
#  conv2d (Conv2D)                (None, 24, 24, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 24, 24, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 24, 24, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 24, 24, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 24, 24, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 24, 24, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 24, 24, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 24, 24, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 24, 24, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 24, 24, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 12, 12, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 12, 12, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 12, 12, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 12, 12, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 12, 12, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 12, 12, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 12, 12, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 12, 12, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 12, 12, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 12, 12, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 6, 6, 728)    186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 6, 6, 728)    0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 6, 6, 728)   2912        ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 6, 6, 728)    0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 6, 6, 728)    0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 6, 6, 728)    0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 6, 6, 728)    0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 6, 6, 728)    0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 6, 6, 728)    0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 6, 6, 728)   536536      ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 6, 6, 728)   0           ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 6, 6, 728)   536536      ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 6, 6, 728)    0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 6, 6, 728)   536536      ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 6, 6, 728)   0           ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 6, 6, 728)   536536      ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 6, 6, 728)    0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 6, 6, 728)   0           ['block12_sepconv2_bn[0][0]']
#  on)
#  block12_sepconv3 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 6, 6, 728)    0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 6, 6, 1024)  752024      ['block13_sepconv2_act[0][0]']
#  v2D)
#
#  block13_sepconv2_bn (BatchNorm  (None, 6, 6, 1024)  4096        ['block13_sepconv2[0][0]']
#  alization)
#
#  conv2d_3 (Conv2D)              (None, 3, 3, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 3, 3, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 3, 3, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 3, 3, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 3, 3, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 3, 3, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 3, 3, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 3, 3, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 3, 3, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 3, 3, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %%
model = tf.keras.Sequential([
            # Note the input shape is the desired size of the image 128x128 with 3 bytes color
            # This is the first convolution
            base_model,
            tf.keras.layers.Conv2D(filters=32, padding='same', kernel_size=3, activation='relu', strides=1),
            tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
            tf.keras.layers.Dropout(rate=0.5),

            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(3, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.001), loss='categorical_crossentropy', metrics='accuracy')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 3, 3, 2048)        20861480
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 32)          589856
#
#  max_pooling2d (MaxPooling2D  (None, 1, 1, 32)         0
#  )
#
#  dropout (Dropout)           (None, 1, 1, 32)          0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 3)                 99
#
# =================================================================
# Total params: 21,451,435
# Trainable params: 589,955
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %% [markdown]
# # TRAIN MODEL

# %%
import time

start_time = time.time()

history = model.fit(x_train, y_train,  # Use x_train instead of x_train_rgb
                    batch_size=32,
                    epochs=10,
                    verbose=2,
                    validation_data=(x_test, y_test))  # Use x_test instead of x_test_rgb

elapsed_time = time.time() - start_time
print("Elapsed time:", elapsed_time)
# Out:
# Epoch 1/10
# 20/20 - 11s - loss: 0.9562 - accuracy: 0.5561 - val_loss: 0.8318 - val_accuracy: 0.5833 - 11s/epoch - 529ms/step
# Epoch 2/10
# 20/20 - 7s - loss: 0.7874 - accuracy: 0.6490 - val_loss: 0.7438 - val_accuracy: 0.6603 - 7s/epoch - 346ms/step
# Epoch 3/10
# 20/20 - 7s - loss: 0.7002 - accuracy: 0.6747 - val_loss: 0.7077 - val_accuracy: 0.6795 - 7s/epoch - 360ms/step
# Epoch 4/10
# 20/20 - 7s - loss: 0.6420 - accuracy: 0.7003 - val_loss: 0.6857 - val_accuracy: 0.7115 - 7s/epoch - 363ms/step
# Epoch 5/10
# 20/20 - 6s - loss: 0.5762 - accuracy: 0.7324 - val_loss: 0.6697 - val_accuracy: 0.7308 - 6s/epoch - 285ms/step
# Epoch 6/10
# 20/20 - 7s - loss: 0.5872 - accuracy: 0.7019 - val_loss: 0.7058 - val_accuracy: 0.7179 - 7s/epoch - 330ms/step
# Epoch 7/10
# 20/20 - 7s - loss: 0.5140 - accuracy: 0.7484 - val_loss: 0.6956 - val_accuracy: 0.7115 - 7s/epoch - 327ms/step
# Epoch 8/10
# 20/20 - 7s - loss: 0.4815 - accuracy: 0.7869 - val_loss: 0.6710 - val_accuracy: 0.7692 - 7s/epoch - 326ms/step
# Epoch 9/10
# 20/20 - 7s - loss: 0.4991 - accuracy: 0.7740 - val_loss: 0.6743 - val_accuracy: 0.7436 - 7s/epoch - 336ms/step
# Epoch 10/10
# 20/20 - 7s - loss: 0.4231 - accuracy: 0.8013 - val_loss: 0.6950 - val_accuracy: 0.7436 - 7s/epoch - 328ms/step
# Elapsed time: 70.69580745697021

# %% [markdown]
# # EVALUATION

# %%
# Evaluate the model on the test data
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.6950439810752869
# Test accuracy: 0.7435897588729858

# %%
from sklearn import metrics

small_x = x_test[1:100]
small_y = y_test[1:100]
small_y2 = np.argmax(small_y,axis=1)
pred = model.predict(small_x)
pred = np.argmax(pred,axis=1)
score = metrics.accuracy_score(small_y2, pred)
print('Accuracy: {}'.format(score))
# Out:
# 4/4 [==============================] - 2s 176ms/step
# Accuracy: 0.7575757575757576

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 

# Predict probabilities for each class
y_pred_probs = model.predict(x_test)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Convert one-hot encoded labels back to original labels
y_true = np.argmax(y_test, axis=1)

# Generate confusion matrix
conf_mat = confusion_matrix(y_true, y_pred)

# Generate classification report
class_rep = classification_report(y_true, y_pred, target_names=label_encoder.classes_)
# Out:
# 5/5 [==============================] - 1s 266ms/step

# %%
# Display classification report
print("Classification Report:\n", class_rep)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.72      0.87      0.79        84
#    malignant       0.79      0.63      0.70        43
#       normal       0.76      0.55      0.64        29
#
#     accuracy                           0.74       156
#    macro avg       0.76      0.68      0.71       156
# weighted avg       0.75      0.74      0.74       156

# %% [markdown]
# # CROSS VALIDATION
# ## Using StratifiedKFold Cross Validation

# %%
from sklearn.model_selection import StratifiedKFold

k = 5
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
cvscores = []
from tensorflow.keras.callbacks import EarlyStopping

for train_index, val_index in skf.split(x_train, np.argmax(y_train, axis=1)):
    x_fold_train, x_fold_val = x_train[train_index], x_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    early_stopping = EarlyStopping(monitor='val_loss', patience=3)

    model.fit(x_fold_train, y_fold_train,
              batch_size=128,
              epochs=12,
              verbose=1,
              validation_data=(x_fold_val, y_fold_val),
              callbacks=[early_stopping])

    scores = model.evaluate(x_fold_val, y_fold_val, verbose=0)
    print(f"Fold accuracy: {scores[1]*100}%")
    cvscores.append(scores[1] * 100)

print(f"Mean accuracy: {np.mean(cvscores)}%")
print(f"Standard deviation: {np.std(cvscores)}%")
# Out:
# Epoch 1/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.4141 - accuracy: 0.8096 - val_loss: 0.2733 - val_accuracy: 0.9520
# Epoch 2/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.4468 - accuracy: 0.7956 - val_loss: 0.2864 - val_accuracy: 0.9280
# Epoch 3/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.4227 - accuracy: 0.8036 - val_loss: 0.2716 - val_accuracy: 0.9520
# Epoch 4/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.4113 - accuracy: 0.8156 - val_loss: 0.2654 - val_accuracy: 0.9280
# Epoch 5/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3878 - accuracy: 0.8176 - val_loss: 0.2564 - val_accuracy: 0.9360
# Epoch 6/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.4136 - accuracy: 0.7876 - val_loss: 0.2510 - val_accuracy: 0.9440
# Epoch 7/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3884 - accuracy: 0.8136 - val_loss: 0.2527 - val_accuracy: 0.9360
# Epoch 8/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3652 - accuracy: 0.8297 - val_loss: 0.2527 - val_accuracy: 0.9520
# Epoch 9/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3513 - accuracy: 0.8377 - val_loss: 0.2502 - val_accuracy: 0.9440
# Epoch 10/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3546 - accuracy: 0.8377 - val_loss: 0.2475 - val_accuracy: 0.9360
# Epoch 11/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3071 - accuracy: 0.8677 - val_loss: 0.2430 - val_accuracy: 0.9360
# Epoch 12/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3274 - accuracy: 0.8277 - val_loss: 0.2439 - val_accuracy: 0.9440
# Fold accuracy: 94.40000057220459%
# Epoch 1/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3587 - accuracy: 0.8277 - val_loss: 0.1947 - val_accuracy: 0.9760
# Epoch 2/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3454 - accuracy: 0.8357 - val_loss: 0.2063 - val_accuracy: 0.9680
# Epoch 3/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3492 - accuracy: 0.8657 - val_loss: 0.2066 - val_accuracy: 0.9760
# Epoch 4/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3277 - accuracy: 0.8517 - val_loss: 0.1985 - val_accuracy: 0.9760
# Fold accuracy: 97.60000109672546%
# Epoch 1/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3165 - accuracy: 0.8657 - val_loss: 0.1817 - val_accuracy: 0.9600
# Epoch 2/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3246 - accuracy: 0.8257 - val_loss: 0.1797 - val_accuracy: 0.9520
# Epoch 3/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3149 - accuracy: 0.8397 - val_loss: 0.1823 - val_accuracy: 0.9600
# Epoch 4/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3212 - accuracy: 0.8457 - val_loss: 0.1845 - val_accuracy: 0.9600
# Epoch 5/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3076 - accuracy: 0.8477 - val_loss: 0.1896 - val_accuracy: 0.9520
# Fold accuracy: 95.20000219345093%
# Epoch 1/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3169 - accuracy: 0.8397 - val_loss: 0.1295 - val_accuracy: 0.9840
# Epoch 2/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3123 - accuracy: 0.8477 - val_loss: 0.1340 - val_accuracy: 0.9840
# Epoch 3/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.2947 - accuracy: 0.8717 - val_loss: 0.1378 - val_accuracy: 0.9920
# Epoch 4/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.3235 - accuracy: 0.8277 - val_loss: 0.1372 - val_accuracy: 0.9840
# Fold accuracy: 98.4000027179718%
# Epoch 1/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.3073 - accuracy: 0.8540 - val_loss: 0.1604 - val_accuracy: 0.9758
# Epoch 2/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.2783 - accuracy: 0.8720 - val_loss: 0.1639 - val_accuracy: 0.9758
# Epoch 3/12
# 4/4 [==============================] - 5s 1s/step - loss: 0.2767 - accuracy: 0.8660 - val_loss: 0.1648 - val_accuracy: 0.9758
# Epoch 4/12
# 4/4 [==============================] - 4s 1s/step - loss: 0.2677 - accuracy: 0.8700 - val_loss: 0.1640 - val_accuracy: 0.9677
# Fold accuracy: 96.77419066429138%
# Mean accuracy: 96.47483944892883%
# Standard deviation: 1.482701580804744%

# %% [markdown]
# # NEW QUERY

# %%
# Save the model
model.save("UltraSound_CNN2.h5")

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("UltraSound_CNN2.h5")
model

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Load the model
model = load_model("UltraSound_CNN2.h5")

# Define a function to preprocess new images
def preprocess_image(img_path):
    img = cv2.imread(img_path)  # Read image
    if img is None:
        print(f"Warning: Unable to read image {img_path}.")
        return None
    img = cv2.resize(img, (100, 100))  # Resize image
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = img.astype('float32') / 255  # Normalize the image
    return img

# Define the path to the new images
new_data_path = "C:/Users/Hp/MACHINE LEARNING/Lab/ML PROJECT/DATA FOR NEW QUERY"
benign_path = os.path.join(new_data_path, "Benign")
malignant_path = os.path.join(new_data_path, "Malignant")

# Load and preprocess new images
def load_new_images(folder_path, label):
    images = []
    labels = []
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)
        img = preprocess_image(img_path)
        if img is not None:
            images.append(img)
            labels.append(label)
    return images, labels

benign_images, benign_labels = load_new_images(benign_path, 'benign')
malignant_images, malignant_labels = load_new_images(malignant_path, 'malignant')

# Combine the images and labels
new_images = benign_images + malignant_images
new_labels = benign_labels + malignant_labels

# Convert list to numpy array
new_images = np.array(new_images)

# Predict the class of new images
predictions = model.predict(new_images)
predicted_classes = np.argmax(predictions, axis=1)

# Decode the predicted labels
label_decoder = {0: 'benign', 1: 'malignant', 2: 'normal'}
decoded_predictions = [label_decoder[pred] for pred in predicted_classes]

# True labels for the new images
true_labels = new_labels

# Encode true labels into integers
label_encoder = {v: k for k, v in label_decoder.items()}
true_labels_encoded = [label_encoder[label] for label in true_labels]
# Out:
# 8/8 [==============================] - 4s 300ms/step

# %%
# Calculate accuracy
accuracy = accuracy_score(true_labels_encoded, predicted_classes)
print(f'Accuracy on new data: {accuracy * 100:.2f}%')

# Display the results
for filename, pred, true_label in zip(os.listdir(benign_path) + os.listdir(malignant_path), decoded_predictions, true_labels):
    print(f"Image: {filename} - Predicted: {pred} - True Label: {true_label}")
# Out:
# Accuracy on new data: 52.59%
# Image: 1 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 10 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 100 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 101 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 102 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 103 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 104 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 105 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 106 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 107 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 108 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 109 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 11 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 12 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 13 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 14 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 15 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 16 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 17 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 18 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 19 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 2 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 20 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 21 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 22 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 23 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 24 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 25 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 26 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 27 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 28 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 29 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 3 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 30 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 31 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 32 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 33 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 34 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 35 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 36 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 37 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 38 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 39 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 4 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 40 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 41 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 42 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 43 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 44 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 45 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 46 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 47 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 48 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 49 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 5 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 50 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 51 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 52 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 53 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 54 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 55 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 56 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 57 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 58 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 59 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 6 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 60 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 61 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 62 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 63 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 64 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 65 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 66 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 67 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 68 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 69 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 7 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 70 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 71 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 72 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 73 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 74 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 75 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 76 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 77 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 78 Benign Image.bmp - Predicted: normal - True Label: benign
# Image: 79 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 8 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 80 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 81 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 82 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 83 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 84 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 85 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 86 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 87 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 88 Benign Image.bmp - Predicted: malignant - True Label: benign
# Image: 89 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 9 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 90 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 91 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 92 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 93 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 94 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 95 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 96 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 97 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 98 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 99 Benign Image.bmp - Predicted: benign - True Label: benign
# Image: 1 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 10 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 100 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 101 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 102 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 103 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 104 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 105 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 106 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 107 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 108 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 109 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 11 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 110 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 111 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 112 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 113 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 114 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 115 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 116 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 117 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 118 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 119 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 12 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 120 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 121 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 122 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 123 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 13 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 14 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 15 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 16 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 17 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 18 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 19 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 2 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 20 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 21 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 22 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 23 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 24 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 25 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 26 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 27 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 28 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 29 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 3 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 30 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 31 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 32 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 33 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 34 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 35 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 36 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 37 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 38 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 39 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 4 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 40 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 41 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 42 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 43 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 44 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 45 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 46 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 47 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 48 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 49 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 5 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 50 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 51 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 52 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 53 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 54 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 55 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 56 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 57 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 58 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 59 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 6 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 60 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 61 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 62 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 63 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 64 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 65 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 66 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 67 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 68 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 69 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 7 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 70 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 71 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 72 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 73 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 74 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 75 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 76 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 77 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 78 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 79 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 8 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 80 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 81 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 82 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 83 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 84 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 85 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 86 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 87 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 88 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 89 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 9 Malignant Image.bmp - Predicted: normal - True Label: malignant
# Image: 90 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 91 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 92 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 93 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 94 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 95 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 96 Malignant Image.bmp - Predicted: malignant - True Label: malignant
# Image: 97 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 98 Malignant Image.bmp - Predicted: benign - True Label: malignant
# Image: 99 Malignant Image.bmp - Predicted: normal - True Label: malignant

# %%
# Optionally, display the images with their predicted labels in a 4x6 grid
def display_predictions(images, predictions, true_labels, num_samples=24):
    plt.figure(figsize=(20, 15))
    for i in range(min(num_samples, len(images))):
        plt.subplot(4, 6, i + 1)
        image = images[i]
        pred_label = predictions[i]
        true_label = true_labels[i]
        color = 'black' if pred_label == true_label else 'red'
        plt.imshow(image)
        plt.title(pred_label, color=color, fontsize=18)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Display the predictions
display_predictions(new_images, decoded_predictions, true_labels)

# %% [markdown]
# ---
